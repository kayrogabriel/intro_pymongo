# %%
# !pip install pymongo[srv]
# Out:
# ...
#   Using cached dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
# ...

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://admin:babalu25@cluster0.83zol.gcp.mongodb.net/anatel?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['anatel',
#  'brasil',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'tabagismo',
#  'test',
#  'admin',
#  'local']

# %%
db = client.anatel

# %%
db.minas
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.83zol.gcp.mongodb.net:27017', 'cluster0-shard-00-02.83zol.gcp.mongodb.net:27017', 'cluster0-shard-00-00.83zol.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-ec2c5q-shard-0', ssl=True), 'anatel'), 'minas')

# %%
#1
db.minas.count_documents({})
# Out:
# 509706

# %%
#2
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb3206692b62044944780b9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb3206692b62044944780ba'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': '8'},
#  {'_id': ObjectId('5fb3206692b62044944780bb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
# ...

# %%
#3
db.minas.find_one(sort=[("QtdeSolic", -1)])
# Out:
# {'_id': ObjectId('5fb321ef92b62044944c243a'),
#  'DataExtracao': '2017-01-08',
#  'Ano': '2016',
#  'Mes': '11',
#  'CanalEntrada': 'Call Center',
#  'Condicao': 'Nova',
#  'GrupoEconNorm': 'VIVO',
#  'Tipo': 'Reclamação',
#  'Servico': 'Celular Pós-Pago',
#  'Modalidade': 'Cobrança',
#  'Motivo': 'Cobrança após cancelamento',
#  'UF': 'MG',
#  'QtdeSolic': '999'}

# %%
#4
db.minas.find_one(sort=[("QtdeSolic", 1)])["QtdeSolic"]
# Out:
# '1'

# %%
#5
agr = [ {'$group': {'_id': '5fb321ef92b62044944c243a', 'all': { '$max': '$QtdeSolic' } } } ]

list(db.minas.cars.aggregate(agr))
# Out:
# []

# %%
#6

# %%
#7

list(db.minas.find({"Tipo": "Reclamação" }))
# Out:
# [{'_id': ObjectId('5fb3206692b62044944780bb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb3206692b62044944780bc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb3206692b62044944780bd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
# ...

# %%
#8
list(db.minas.distinct("Tipo"));
